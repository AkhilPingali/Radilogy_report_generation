# %%
import os
import glob
import xml.etree.ElementTree as ET
import pandas as pd
from pathlib import Path

def extract_image_info_from_report(xml_content):
    """
    Parse XML report content and extract the report ID and associated image IDs.
    
    Args:
        xml_content: String containing XML content
        
    Returns:
        A tuple of (report_id, list_of_image_ids, report_findings, report_impression)
    """
    try:
        # Parse the XML string
        root = ET.fromstring(xml_content)
        
        # Extract report ID
        uid_element = root.find('.//uId')
        report_id = uid_element.get('id') if uid_element is not None else None
        
        # Extract findings and impression if available
        findings_element = root.find('.//AbstractText[@Label="FINDINGS"]')
        findings = findings_element.text if findings_element is not None else None
        
        impression_element = root.find('.//AbstractText[@Label="IMPRESSION"]')
        impression = impression_element.text if impression_element is not None else None
        
        # Extract all parentImage elements to get associated image IDs
        parent_images = root.findall('.//parentImage')
        image_ids = [img.get('id') for img in parent_images if img.get('id') is not None]
        
        return report_id, image_ids, findings, impression
    
    except Exception as e:
        print(f"Error processing XML content: {e}")
        return None, [], None, None

def find_xml_files(directory):
    """
    Recursively find all XML files in the given directory and its subdirectories
    """
    xml_files = []
    
    # Check if directory exists
    if not os.path.exists(directory):
        print(f"Directory not found: {directory}")
        return xml_files
    
    # Walk through directory and all subdirectories
    for root, dirs, files in os.walk(directory):
        for file in files:
            # Check for XML files
            if file.endswith('.xml'):
                xml_files.append(os.path.join(root, file))
            # Also check for files that might contain XML content but don't have .xml extension
            elif file == 'paste.txt' or 'report' in file.lower():
                xml_files.append(os.path.join(root, file))
    
    print(f"Found {len(xml_files)} potential XML files in {directory}")
    return xml_files

def map_reports_to_images(reports_dir, output_file='mapping_results.csv'):
    """
    Process all XML report files in the given directory and create a mapping
    between reports and their associated images.
    
    Args:
        reports_dir: Directory containing the XML report files
        output_file: File to save the mapping results
    """
    # Find all potential XML files in the reports directory
    xml_files = find_xml_files(reports_dir)
    
    # Lists to store the mapping data
    all_report_ids = []
    all_image_ids = []
    all_findings = []
    all_impressions = []
    
    # Process each file
    for xml_file in xml_files:
        try:
            with open(xml_file, 'r', encoding='utf-8') as f:
                xml_content = f.read()
                
            # Check if this is actually XML content
            if '<?xml' in xml_content:
                report_id, image_ids, findings, impression = extract_image_info_from_report(xml_content)
                if report_id and image_ids:
                    print(f"Found report {report_id} with {len(image_ids)} images")
                    for img_id in image_ids:
                        all_report_ids.append(report_id)
                        all_image_ids.append(img_id)
                        all_findings.append(findings)
                        all_impressions.append(impression)
        except Exception as e:
            print(f"Error reading file {xml_file}: {e}")
    
    # Create a DataFrame with the mapping data
    mapping_df = pd.DataFrame({
        'ReportID': all_report_ids,
        'ImageID': all_image_ids,
        'Findings': all_findings,
        'Impression': all_impressions
    })
    
    # Save the mapping to a CSV file
    mapping_df.to_csv(output_file, index=False)
    print(f"Mapping saved to {output_file}")
    
    return mapping_df

def verify_image_existence(mapping_df, png_dir):
    """
    Verify that the PNG files corresponding to the image IDs exist in the given directory.
    
    Args:
        mapping_df: DataFrame containing the mapping between reports and images
        png_dir: Directory containing the PNG image files
    
    Returns:
        DataFrame with an additional column indicating if the image file exists
    """
    # Check if directory exists
    if not os.path.exists(png_dir):
        print(f"PNG directory not found: {png_dir}")
        if len(mapping_df) > 0:
            mapping_df['ImageExists'] = False
        return mapping_df
    
    # Check if DataFrame is empty
    if len(mapping_df) == 0:
        print("No mappings found to verify")
        return mapping_df
    
    # Add a column to track if the image file exists
    mapping_df['ImageExists'] = False
    mapped_to_png = []
    
    # Check each image ID
    for i, image_id in enumerate(mapping_df['ImageID']):
        # Try different potential file patterns
        for pattern in [
            f"{image_id}.png",  # Direct match
            f"{image_id.lower()}.png",  # Lowercase
            f"{image_id.replace('CXR', 'cxr')}.png",  # Different case format
            f"{image_id.split('_')[1]}.png"  # Just the IM-XXXX part
        ]:
            # Check for the file using a recursive search
            found = False
            for root, dirs, files in os.walk(png_dir):
                if pattern in files:
                    mapping_df.at[i, 'ImageExists'] = True
                    mapped_to_png.append(os.path.join(root, pattern))
                    found = True
                    break
            
            if found:
                break
    
    # Print a summary
    existing_count = mapping_df['ImageExists'].sum()
    total_count = len(mapping_df)
    if total_count > 0:
        print(f"Found {existing_count} out of {total_count} images ({existing_count/total_count*100:.2f}%)")
        if existing_count > 0:
            print(f"Sample matched PNG paths:")
            for path in mapped_to_png[:5]:  # Show first 5 examples
                print(f"  {path}")
    else:
        print("No images to verify")
    
    return mapping_df

def main():
    # Set the directories containing the XML reports and PNG images
    reports_dir = input("Enter the directory containing XML reports: ")
    png_dir = input("Enter the directory containing PNG images: ")
    
    # Create the mapping
    mapping_df = map_reports_to_images(reports_dir)
    
    # Verify image existence
    mapping_df = verify_image_existence(mapping_df, png_dir)
    
    # Save the updated mapping
    mapping_df.to_csv('verified_mapping_results.csv', index=False)
    print("Verified mapping saved to verified_mapping_results.csv")
    
    # Display some statistics
    print("\nMapping Statistics:")
    print(f"Total reports: {mapping_df['ReportID'].nunique()}")
    print(f"Total images: {len(mapping_df)}")
    
    # Avoid division by zero
    unique_reports = mapping_df['ReportID'].nunique()
    if unique_reports > 0:
        print(f"Average images per report: {len(mapping_df) / unique_reports:.2f}")
        
        # Display reports with multiple images
        report_counts = mapping_df['ReportID'].value_counts()
        multi_image_reports = report_counts[report_counts > 1]
        print(f"\nReports with multiple images: {len(multi_image_reports)}")
        if len(multi_image_reports) > 0:
            print("Top 5 reports with the most images:")
            print(multi_image_reports.head())
    else:
        print("No reports found to calculate statistics.")

if __name__ == "__main__":
    main()
# Out:
# Enter the directory containing XML reports:  /Users/nuthankishoremaddineni/Downloads/ecgen-radiology
# Enter the directory containing PNG images:  /Users/nuthankishoremaddineni/Downloads/NLMCXR_png
# Found 3955 potential XML files in /Users/nuthankishoremaddineni/Downloads/ecgen-radiology
# Found report CXR162 with 2 images
# Found report CXR1390 with 2 images
# Found report CXR604 with 2 images
# Found report CXR2699 with 2 images
# Found report CXR2841 with 1 images
# Found report CXR3587 with 2 images
# Found report CXR2855 with 2 images
# Found report CXR3593 with 2 images
# Found report CXR88 with 1 images
# Found report CXR610 with 1 images
# Found report CXR1384 with 2 images
# Found report CXR176 with 2 images
# Found report CXR638 with 3 images
# Found report CXR1435 with 2 images
# Found report CXR3222 with 2 images
# Found report CXR2882 with 2 images
# Found report CXR3544 with 2 images
# Found report CXR1353 with 2 images
# Found report CXR1347 with 2 images
# Found report CXR3550 with 1 images
# Found report CXR2128 with 2 images
# Found report CXR3236 with 2 images
# Found report CXR1421 with 1 images
# Found report CXR2100 with 2 images
# Found report CXR1409 with 2 images
# Found report CXR63 with 2 images
# Found report CXR3578 with 2 images
# Found report CXR2666 with 2 images
# Found report CXR2672 with 2 images
# Found report CXR77 with 3 images
# Found report CXR837 with 2 images
# Found report CXR189 with 2 images
# Found report CXR2114 with 2 images
# Found report CXR3785 with 2 images
# Found report CXR406 with 2 images
# Found report CXR1192 with 2 images
# Found report CXR360 with 2 images
# Found report CXR1838 with 1 images
# Found report CXR374 with 2 images
# Found report CXR412 with 2 images
# Found report CXR3791 with 2 images
# Found report CXR3949 with 2 images
# Found report CXR3961 with 2 images
# Found report CXR1810 with 2 images
# Found report CXR1804 with 2 images
# Found report CXR348 with 2 images
# Found report CXR3975 with 2 images
# Found report CXR1151 with 2 images
# Found report CXR2458 with 2 images
# Found report CXR3746 with 2 images
# Found report CXR3020 with 2 images
# Found report CXR1637 with 1 images
# Found report CXR1623 with 2 images
# Found report CXR3034 with 2 images
# Found report CXR3752 with 2 images
# Found report CXR1145 with 2 images
# Found report CXR2464 with 2 images
# Found report CXR2302 with 1 images
# Found report CXR3008 with 2 images
# Found report CXR2316 with 2 images
# Found report CXR1179 with 2 images
# Found report CXR2470 with 3 images
# Found report CXR3829 with 2 images
# Found report CXR572 with 2 images
# Found report CXR214 with 1 images
# Found report CXR1780 with 2 images
# Found report CXR1958 with 2 images
# Found report CXR3197 with 2 images
# Found report CXR2289 with 2 images
# Found report CXR3183 with 2 images
# Found report CXR1794 with 2 images
# Found report CXR200 with 2 images
# Found report CXR3815 with 2 images
# Found report CXR228 with 2 images
# Found report CXR1964 with 2 images
# Found report CXR1970 with 2 images
# Found report CXR3801 with 1 images
# Found report CXR1025 with 2 images
# Found report CXR3632 with 2 images
# Found report CXR3154 with 2 images
# Found report CXR1743 with 2 images
# Found report CXR1757 with 1 images
# Found report CXR3140 with 2 images
# Found report CXR3626 with 2 images
# Found report CXR2538 with 2 images
# Found report CXR1031 with 1 images
# Found report CXR2510 with 2 images
# Found report CXR1019 with 2 images
# Found report CXR2276 with 2 images
# Found report CXR3168 with 2 images
# Found report CXR2262 with 2 images
# Found report CXR599 with 2 images
# Found report CXR2504 with 2 images
# Found report CXR3395 with 2 images
# Found report CXR1582 with 2 images
# Found report CXR770 with 2 images
# Found report CXR2935 with 2 images
# Found report CXR2921 with 1 images
# Found report CXR764 with 2 images
# Found report CXR1596 with 2 images
# Found report CXR3381 with 2 images
# Found report CXR2909 with 2 images
# Found report CXR994 with 2 images
# Found report CXR758 with 2 images
# Found report CXR980 with 2 images
# Found report CXR1541 with 2 images
# Found report CXR3356 with 1 images
# Found report CXR2048 with 2 images
# Found report CXR3430 with 2 images
# Found report CXR1233 with 2 images
# Found report CXR3424 with 2 images
# Found report CXR3342 with 2 images
# Found report CXR1555 with 2 images
# Found report CXR2074 with 2 images
# Found report CXR957 with 2 images
# Found report CXR2712 with 2 images
# Found report CXR2706 with 2 images
# Found report CXR3418 with 2 images
# Found report CXR943 with 2 images
# Found report CXR1569 with 2 images
# Found report CXR2060 with 2 images
# Found report CXR942 with 2 images
# Found report CXR3419 with 3 images
# Found report CXR2061 with 2 images
# Found report CXR1568 with 2 images
# Found report CXR2075 with 2 images
# Found report CXR2713 with 2 images
# Found report CXR956 with 1 images
# Found report CXR1232 with 2 images
# Found report CXR1554 with 2 images
# Found report CXR3343 with 1 images
# Found report CXR2049 with 2 images
# Found report CXR3357 with 2 images
# Found report CXR1540 with 2 images
# Found report CXR1226 with 2 images
# Found report CXR3431 with 2 images
# Found report CXR981 with 1 images
# Found report CXR759 with 2 images
# Found report CXR995 with 2 images
# Found report CXR2908 with 2 images
# Found report CXR765 with 2 images
# Found report CXR2920 with 2 images
# Found report CXR3380 with 2 images
# Found report CXR1597 with 2 images
# Found report CXR1583 with 2 images
# Found report CXR3394 with 2 images
# Found report CXR2934 with 2 images
# Found report CXR771 with 3 images
# Found report CXR2263 with 2 images
# Found report CXR2505 with 2 images
# Found report CXR598 with 2 images
# Found report CXR1018 with 2 images
# Found report CXR2511 with 2 images
# Found report CXR3169 with 2 images
# Found report CXR2277 with 2 images
# Found report CXR3141 with 2 images
# Found report CXR1756 with 2 images
# Found report CXR1030 with 2 images
# Found report CXR2539 with 3 images
# Found report CXR3627 with 1 images
# Found report CXR3633 with 2 images
# Found report CXR1024 with 1 images
# Found report CXR1742 with 2 images
# Found report CXR3155 with 2 images
# Found report CXR1971 with 2 images
# Found report CXR3814 with 2 images
# Found report CXR1965 with 2 images
# Found report CXR229 with 2 images
# Found report CXR201 with 2 images
# Found report CXR1795 with 2 images
# Found report CXR3182 with 2 images
# Found report CXR567 with 2 images
# Found report CXR573 with 3 images
# Found report CXR3828 with 2 images
# Found report CXR2288 with 2 images
# Found report CXR3196 with 2 images
# Found report CXR1959 with 2 images
# Found report CXR1781 with 2 images
# Found report CXR215 with 2 images
# Found report CXR2317 with 2 images
# Found report CXR3009 with 1 images
# Found report CXR2471 with 2 images
# Found report CXR1178 with 2 images
# Found report CXR2465 with 2 images
# Found report CXR2303 with 2 images
# Found report CXR1622 with 2 images
# Found report CXR1144 with 2 images
# Found report CXR3753 with 2 images
# Found report CXR3747 with 2 images
# Found report CXR2459 with 2 images
# Found report CXR1150 with 1 images
# Found report CXR1636 with 2 images
# Found report CXR3021 with 2 images
# Found report CXR349 with 2 images
# Found report CXR1805 with 2 images
# Found report CXR3974 with 2 images
# Found report CXR3960 with 2 images
# Found report CXR1811 with 1 images
# Found report CXR375 with 2 images
# Found report CXR1839 with 2 images
# Found report CXR3948 with 2 images
# Found report CXR3790 with 2 images
# Found report CXR413 with 2 images
# Found report CXR1187 with 2 images
# Found report CXR1193 with 2 images
# Found report CXR407 with 2 images
# Found report CXR3784 with 2 images
# Found report CXR361 with 2 images
# Found report CXR836 with 2 images
# Found report CXR76 with 2 images
# Found report CXR2673 with 2 images
# Found report CXR2115 with 2 images
# Found report CXR188 with 2 images
# Found report CXR1408 with 1 images
# Found report CXR2667 with 2 images
# Found report CXR3579 with 2 images
# Found report CXR822 with 2 images
# Found report CXR62 with 3 images
# Found report CXR3551 with 3 images
# Found report CXR2897 with 2 images
# Found report CXR1346 with 3 images
# Found report CXR1420 with 3 images
# Found report CXR3237 with 1 images
# Found report CXR2129 with 2 images
# Found report CXR3223 with 2 images
# Found report CXR1434 with 2 images
# Found report CXR1352 with 2 images
# Found report CXR3545 with 2 images
# Found report CXR2868 with 2 images
# Found report CXR639 with 2 images
# Found report CXR1385 with 2 images
# Found report CXR611 with 2 images
# Found report CXR89 with 2 images
# Found report CXR3592 with 2 images
# Found report CXR2854 with 2 images
# Found report CXR177 with 2 images
# Found report CXR163 with 3 images
# Found report CXR3586 with 2 images
# Found report CXR2840 with 3 images
# Found report CXR2698 with 2 images
# Found report CXR605 with 2 images
# Found report CXR1391 with 2 images
# Found report CXR175 with 1 images
# Found report CXR2856 with 2 images
# Found report CXR3590 with 2 images
# Found report CXR613 with 2 images
# Found report CXR1387 with 1 images
# Found report CXR1393 with 2 images
# Found report CXR607 with 2 images
# Found report CXR2842 with 2 images
# Found report CXR3584 with 1 images
# Found report CXR161 with 2 images
# Found report CXR149 with 2 images
# Found report CXR3235 with 2 images
# Found report CXR1422 with 2 images
# Found report CXR48 with 2 images
# Found report CXR1344 with 2 images
# Found report CXR808 with 2 images
# Found report CXR2895 with 2 images
# Found report CXR3553 with 2 images
# Found report CXR2881 with 1 images
# Found report CXR3547 with 2 images
# Found report CXR2659 with 2 images
# Found report CXR1350 with 2 images
# Found report CXR1436 with 2 images
# Found report CXR3221 with 2 images
# Found report CXR2117 with 2 images
# Found report CXR3209 with 2 images
# Found report CXR2671 with 2 images
# Found report CXR74 with 1 images
# Found report CXR1378 with 2 images
# Found report CXR834 with 2 images
# Found report CXR60 with 1 images
# Found report CXR820 with 2 images
# Found report CXR2665 with 2 images
# Found report CXR2103 with 2 images
# Found report CXR411 with 2 images
# Found report CXR3792 with 2 images
# Found report CXR377 with 2 images
# Found report CXR363 with 2 images
# Found report CXR3786 with 1 images
# Found report CXR2498 with 2 images
# Found report CXR405 with 2 images
# Found report CXR1191 with 2 images
# Found report CXR3976 with 2 images
# Found report CXR1807 with 2 images
# Found report CXR1813 with 2 images
# Found report CXR439 with 2 images
# Found report CXR3962 with 2 images
# Found report CXR3989 with 2 images
# Found report CXR3751 with 2 images
# Found report CXR1146 with 2 images
# Found report CXR1620 with 2 images
# Found report CXR3037 with 2 images
# Found report CXR2329 with 1 images
# Found report CXR3023 with 1 images
# Found report CXR1634 with 2 images
# Found report CXR1152 with 2 images
# Found report CXR3745 with 2 images
# Found report CXR2473 with 2 images
# Found report CXR2315 with 2 images
# Found report CXR388 with 2 images
# Found report CXR1608 with 2 images
# Found report CXR2301 with 2 images
# Found report CXR2467 with 2 images
# Found report CXR3779 with 2 images
# Found report CXR565 with 2 images
# Found report CXR3180 with 2 images
# Found report CXR1797 with 2 images
# Found report CXR203 with 1 images
# Found report CXR217 with 2 images
# Found report CXR1783 with 2 images
# Found report CXR3194 with 2 images
# Found report CXR571 with 2 images
# Found report CXR3802 with 2 images
# Found report CXR559 with 2 images
# Found report CXR1973 with 2 images
# Found report CXR1967 with 2 images
# Found report CXR3816 with 2 images
# Found report CXR3625 with 2 images
# Found report CXR1032 with 2 images
# Found report CXR1754 with 2 images
# Found report CXR3143 with 2 images
# Found report CXR2249 with 2 images
# Found report CXR3157 with 2 images
# Found report CXR1740 with 2 images
# Found report CXR1026 with 1 images
# Found report CXR3631 with 2 images
# Found report CXR3619 with 2 images
# Found report CXR2507 with 2 images
# Found report CXR2261 with 2 images
# Found report CXR1768 with 3 images
# Found report CXR2275 with 2 images
# Found report CXR2513 with 1 images
# Found report CXR1595 with 2 images
# Found report CXR3382 with 2 images
# Found report CXR2922 with 3 images
# Found report CXR767 with 2 images
# Found report CXR773 with 2 images
# Found report CXR2936 with 3 images
# Found report CXR2088 with 2 images
# Found report CXR3396 with 2 images
# Found report CXR1581 with 2 images
# Found report CXR983 with 2 images
# Found report CXR997 with 2 images
# Found report CXR3341 with 2 images
# Found report CXR1556 with 2 images
# Found report CXR1230 with 3 images
# Found report CXR2739 with 2 images
# Found report CXR3427 with 2 images
# Found report CXR3433 with 2 images
# Found report CXR968 with 2 images
# Found report CXR1224 with 1 images
# Found report CXR1542 with 2 images
# Found report CXR3355 with 2 images
# Found report CXR2063 with 2 images
# Found report CXR2705 with 1 images
# Found report CXR940 with 2 images
# Found report CXR798 with 2 images
# Found report CXR954 with 1 images
# Found report CXR1218 with 2 images
# Found report CXR2711 with 2 images
# Found report CXR3369 with 2 images
# Found report CXR2077 with 2 images
# Found report CXR2710 with 2 images
# Found report CXR1219 with 2 images
# Found report CXR955 with 2 images
# Found report CXR3368 with 2 images
# Found report CXR2062 with 2 images
# Found report CXR799 with 2 images
# Found report CXR941 with 2 images
# Found report CXR2704 with 2 images
# Found report CXR1225 with 2 images
# Found report CXR969 with 2 images
# Found report CXR3432 with 2 images
# Found report CXR3354 with 2 images
# Found report CXR1543 with 2 images
# Found report CXR1557 with 1 images
# Found report CXR3340 with 2 images
# Found report CXR3426 with 2 images
# Found report CXR2738 with 2 images
# Found report CXR1231 with 2 images
# Found report CXR996 with 2 images
# Found report CXR982 with 2 images
# Found report CXR2937 with 2 images
# Found report CXR772 with 1 images
# Found report CXR1580 with 2 images
# Found report CXR2089 with 2 images
# Found report CXR3383 with 2 images
# Found report CXR1594 with 2 images
# Found report CXR766 with 1 images
# Found report CXR2923 with 2 images
# Found report CXR2274 with 1 images
# Found report CXR2512 with 1 images
# Found report CXR2506 with 2 images
# Found report CXR3618 with 2 images
# Found report CXR1769 with 1 images
# Found report CXR2260 with 2 images
# Found report CXR1999 with 2 images
# Found report CXR3156 with 2 images
# Found report CXR2248 with 2 images
# Found report CXR3630 with 2 images
# Found report CXR1027 with 2 images
# Found report CXR1033 with 2 images
# Found report CXR3624 with 2 images
# Found report CXR3142 with 3 images
# Found report CXR1755 with 2 images
# Found report CXR1966 with 2 images
# Found report CXR3817 with 2 images
# Found report CXR558 with 2 images
# Found report CXR3803 with 2 images
# Found report CXR1972 with 2 images
# Found report CXR3195 with 2 images
# Found report CXR1782 with 2 images
# Found report CXR216 with 1 images
# Found report CXR570 with 2 images
# Found report CXR564 with 2 images
# Found report CXR202 with 2 images
# Found report CXR1796 with 2 images
# Found report CXR3181 with 1 images
# Found report CXR2300 with 2 images
# Found report CXR1609 with 2 images
# Found report CXR3778 with 2 images
# Found report CXR2466 with 2 images
# Found report CXR2472 with 1 images
# Found report CXR389 with 1 images
# Found report CXR2314 with 2 images
# Found report CXR1635 with 2 images
# Found report CXR3022 with 2 images
# Found report CXR3744 with 2 images
# Found report CXR1153 with 2 images
# Found report CXR1147 with 1 images
# Found report CXR3750 with 1 images
# Found report CXR3988 with 2 images
# Found report CXR2328 with 2 images
# Found report CXR3036 with 2 images
# Found report CXR1621 with 2 images
# Found report CXR1812 with 2 images
# Found report CXR3963 with 1 images
# Found report CXR438 with 2 images
# Found report CXR3977 with 2 images
# Found report CXR1806 with 1 images
# Found report CXR362 with 2 images
# Found report CXR1190 with 3 images
# Found report CXR404 with 2 images
# Found report CXR2499 with 2 images
# Found report CXR3787 with 2 images
# Found report CXR3793 with 1 images
# Found report CXR410 with 2 images
# Found report CXR1184 with 2 images
# Found report CXR376 with 2 images
# Found report CXR2664 with 2 images
# Found report CXR821 with 1 images
# Found report CXR61 with 2 images
# Found report CXR2102 with 2 images
# Found report CXR3208 with 2 images
# Found report CXR2116 with 2 images
# Found report CXR835 with 2 images
# Found report CXR1379 with 2 images
# Found report CXR75 with 2 images
# Found report CXR2670 with 2 images
# Found report CXR1351 with 2 images
# Found report CXR2658 with 2 images
# Found report CXR3546 with 2 images
# Found report CXR2880 with 2 images
# Found report CXR3220 with 2 images
# Found report CXR1437 with 2 images
# Found report CXR1423 with 2 images
# Found report CXR3234 with 2 images
# Found report CXR3552 with 2 images
# Found report CXR2894 with 2 images
# Found report CXR809 with 2 images
# Found report CXR1345 with 2 images
# Found report CXR49 with 2 images
# Found report CXR3585 with 2 images
# Found report CXR2843 with 2 images
# Found report CXR606 with 2 images
# Found report CXR1392 with 2 images
# Found report CXR160 with 2 images
# Found report CXR174 with 2 images
# Found report CXR1386 with 2 images
# Found report CXR612 with 2 images
# Found report CXR3591 with 2 images
# Found report CXR2857 with 2 images
# Found report CXR158 with 2 images
# Found report CXR3595 with 2 images
# Found report CXR616 with 2 images
# Found report CXR1382 with 2 images
# Found report CXR170 with 3 images
# Found report CXR164 with 2 images
# Found report CXR1396 with 2 images
# Found report CXR602 with 2 images
# Found report CXR3581 with 2 images
# Found report CXR2847 with 2 images
# Found report CXR2674 with 2 images
# Found report CXR71 with 1 images
# Found report CXR831 with 2 images
# Found report CXR2112 with 2 images
# Found report CXR2106 with 2 images
# Found report CXR3218 with 3 images
# Found report CXR1369 with 2 images
# Found report CXR65 with 2 images
# Found report CXR825 with 2 images
# Found report CXR2660 with 2 images
# Found report CXR1341 with 2 images
# Found report CXR3556 with 2 images
# Found report CXR2890 with 3 images
# Found report CXR2648 with 1 images
# Found report CXR3230 with 2 images
# Found report CXR1427 with 1 images
# Found report CXR1433 with 2 images
# Found report CXR3224 with 2 images
# Found report CXR3542 with 2 images
# Found report CXR2884 with 2 images
# Found report CXR1355 with 2 images
# Found report CXR59 with 2 images
# Found report CXR819 with 2 images
# Found report CXR1802 with 2 images
# Found report CXR3973 with 1 images
# Found report CXR428 with 2 images
# Found report CXR3967 with 2 images
# Found report CXR1816 with 2 images
# Found report CXR372 with 3 images
# Found report CXR1180 with 2 images
# Found report CXR414 with 2 images
# Found report CXR3797 with 3 images
# Found report CXR2489 with 2 images
# Found report CXR3783 with 1 images
# Found report CXR400 with 1 images
# Found report CXR1194 with 1 images
# Found report CXR366 with 2 images
# Found report CXR2310 with 2 images
# Found report CXR1619 with 2 images
# Found report CXR2476 with 2 images
# Found report CXR3768 with 2 images
# Found report CXR2462 with 2 images
# Found report CXR399 with 2 images
# Found report CXR2304 with 2 images
# Found report CXR1625 with 2 images
# Found report CXR3032 with 2 images
# Found report CXR3754 with 2 images
# Found report CXR1143 with 2 images
# Found report CXR1157 with 2 images
# Found report CXR3998 with 2 images
# Found report CXR3740 with 2 images
# Found report CXR3026 with 3 images
# Found report CXR2338 with 3 images
# Found report CXR1631 with 2 images
# Found report CXR1976 with 3 images
# Found report CXR3807 with 2 images
# Found report CXR548 with 2 images
# Found report CXR3813 with 2 images
# Found report CXR1962 with 2 images
# Found report CXR3185 with 2 images
# Found report CXR1792 with 2 images
# Found report CXR206 with 1 images
# Found report CXR560 with 1 images
# Found report CXR212 with 3 images
# Found report CXR1786 with 2 images
# Found report CXR3191 with 2 images
# Found report CXR2264 with 2 images
# Found report CXR2502 with 2 images
# Found report CXR3608 with 2 images
# Found report CXR2516 with 2 images
# Found report CXR1779 with 2 images
# Found report CXR2270 with 2 images
# Found report CXR1751 with 2 images
# Found report CXR2258 with 2 images
# Found report CXR3146 with 2 images
# Found report CXR3620 with 2 images
# Found report CXR1037 with 2 images
# Found report CXR1023 with 2 images
# Found report CXR3634 with 2 images
# Found report CXR3152 with 2 images
# Found report CXR1745 with 2 images
# Found report CXR986 with 2 images
# Found report CXR992 with 2 images
# Found report CXR2927 with 2 images
# Found report CXR762 with 2 images
# Found report CXR1590 with 2 images
# Found report CXR2099 with 2 images
# Found report CXR3387 with 2 images
# Found report CXR3393 with 2 images
# Found report CXR1584 with 2 images
# Found report CXR776 with 2 images
# Found report CXR2933 with 3 images
# Found report CXR2700 with 2 images
# Found report CXR945 with 2 images
# Found report CXR1209 with 2 images
# Found report CXR3378 with 2 images
# Found report CXR2066 with 2 images
# Found report CXR2072 with 2 images
# Found report CXR951 with 2 images
# Found report CXR2714 with 2 images
# Found report CXR979 with 2 images
# Found report CXR1235 with 2 images
# Found report CXR3422 with 2 images
# Found report CXR3344 with 2 images
# Found report CXR1553 with 2 images
# Found report CXR1547 with 2 images
# Found report CXR3350 with 2 images
# Found report CXR2728 with 2 images
# Found report CXR3436 with 2 images
# Found report CXR1221 with 2 images
# Found report CXR1546 with 2 images
# Found report CXR1220 with 3 images
# Found report CXR3437 with 2 images
# Found report CXR2729 with 2 images
# Found report CXR3423 with 2 images
# Found report CXR1234 with 2 images
# Found report CXR978 with 1 images
# Found report CXR1552 with 2 images
# Found report CXR3345 with 2 images
# Found report CXR2073 with 2 images
# Found report CXR2715 with 2 images
# Found report CXR788 with 2 images
# Found report CXR950 with 2 images
# Found report CXR1208 with 3 images
# Found report CXR944 with 2 images
# Found report CXR2701 with 2 images
# Found report CXR2067 with 2 images
# Found report CXR3379 with 2 images
# Found report CXR1585 with 2 images
# Found report CXR3392 with 2 images
# Found report CXR2932 with 2 images
# Found report CXR777 with 2 images
# Found report CXR763 with 2 images
# Found report CXR2926 with 2 images
# Found report CXR3386 with 2 images
# Found report CXR2098 with 2 images
# Found report CXR1591 with 2 images
# Found report CXR993 with 2 images
# Found report CXR987 with 1 images
# Found report CXR3635 with 2 images
# Found report CXR1022 with 2 images
# Found report CXR1744 with 2 images
# Found report CXR3153 with 2 images
# Found report CXR3147 with 1 images
# Found report CXR2259 with 2 images
# Found report CXR1750 with 2 images
# Found report CXR1988 with 2 images
# Found report CXR1036 with 1 images
# Found report CXR3621 with 2 images
# Found report CXR2517 with 2 images
# Found report CXR3609 with 2 images
# Found report CXR2271 with 1 images
# Found report CXR1778 with 2 images
# Found report CXR2265 with 2 images
# Found report CXR2503 with 2 images
# Found report CXR575 with 2 images
# Found report CXR3190 with 2 images
# Found report CXR1787 with 2 images
# Found report CXR207 with 2 images
# Found report CXR1793 with 1 images
# Found report CXR3184 with 2 images
# Found report CXR561 with 1 images
# Found report CXR3812 with 1 images
# Found report CXR549 with 2 images
# Found report CXR1963 with 2 images
# Found report CXR1977 with 2 images
# Found report CXR3806 with 2 images
# Found report CXR3741 with 1 images
# Found report CXR3999 with 2 images
# Found report CXR1156 with 2 images
# Found report CXR1630 with 2 images
# Found report CXR2339 with 1 images
# Found report CXR3027 with 1 images
# Found report CXR3033 with 1 images
# Found report CXR1624 with 2 images
# Found report CXR1142 with 2 images
# Found report CXR3755 with 2 images
# Found report CXR2463 with 2 images
# Found report CXR2305 with 2 images
# Found report CXR398 with 2 images
# Found report CXR1618 with 2 images
# Found report CXR2311 with 2 images
# Found report CXR3769 with 1 images
# Found report CXR2477 with 2 images
# Found report CXR1195 with 2 images
# Found report CXR401 with 2 images
# Found report CXR3782 with 1 images
# Found report CXR367 with 2 images
# Found report CXR373 with 2 images
# Found report CXR2488 with 1 images
# Found report CXR3796 with 2 images
# Found report CXR415 with 2 images
# Found report CXR3966 with 2 images
# Found report CXR1817 with 1 images
# Found report CXR1803 with 3 images
# Found report CXR429 with 2 images
# Found report CXR3972 with 2 images
# Found report CXR3225 with 2 images
# Found report CXR1432 with 2 images
# Found report CXR818 with 2 images
# Found report CXR58 with 2 images
# Found report CXR1354 with 2 images
# Found report CXR2885 with 2 images
# Found report CXR3543 with 2 images
# Found report CXR2649 with 1 images
# Found report CXR2891 with 1 images
# Found report CXR3557 with 2 images
# Found report CXR1340 with 2 images
# Found report CXR1426 with 2 images
# Found report CXR3231 with 2 images
# Found report CXR3219 with 2 images
# Found report CXR2661 with 2 images
# Found report CXR824 with 2 images
# Found report CXR64 with 2 images
# Found report CXR1368 with 2 images
# Found report CXR830 with 2 images
# Found report CXR70 with 2 images
# Found report CXR2113 with 2 images
# Found report CXR165 with 2 images
# Found report CXR3580 with 2 images
# Found report CXR603 with 2 images
# Found report CXR1397 with 2 images
# Found report CXR1383 with 2 images
# Found report CXR617 with 2 images
# Found report CXR2852 with 2 images
# Found report CXR3594 with 2 images
# Found report CXR171 with 2 images
# Found report CXR159 with 2 images
# Found report CXR2878 with 1 images
# Found report CXR629 with 2 images
# Found report CXR1395 with 2 images
# Found report CXR601 with 2 images
# Found report CXR99 with 2 images
# Found report CXR3582 with 2 images
# Found report CXR2844 with 2 images
# Found report CXR167 with 2 images
# Found report CXR173 with 2 images
# Found report CXR2688 with 2 images
# Found report CXR3596 with 2 images
# Found report CXR2850 with 2 images
# Found report CXR615 with 2 images
# Found report CXR1381 with 2 images
# Found report CXR66 with 2 images
# Found report CXR826 with 2 images
# Found report CXR2663 with 2 images
# Found report CXR2105 with 2 images
# Found report CXR198 with 1 images
# Found report CXR1418 with 2 images
# Found report CXR2111 with 2 images
# Found report CXR3569 with 1 images
# Found report CXR2677 with 2 images
# Found report CXR72 with 2 images
# Found report CXR832 with 2 images
# Found report CXR3541 with 2 images
# Found report CXR2887 with 3 images
# Found report CXR1356 with 2 images
# Found report CXR1430 with 1 images
# Found report CXR2139 with 2 images
# Found report CXR8 with 2 images
# Found report CXR3227 with 2 images
# Found report CXR3233 with 2 images
# Found report CXR1424 with 2 images
# Found report CXR1342 with 2 images
# Found report CXR3555 with 1 images
# Found report CXR2893 with 2 images
# Found report CXR1815 with 2 images
# Found report CXR359 with 2 images
# Found report CXR3964 with 2 images
# Found report CXR3970 with 2 images
# Found report CXR1801 with 2 images
# Found report CXR1829 with 2 images
# Found report CXR365 with 2 images
# Found report CXR3780 with 2 images
# Found report CXR3958 with 2 images
# Found report CXR403 with 2 images
# Found report CXR1197 with 2 images
# Found report CXR1183 with 2 images
# Found report CXR417 with 2 images
# Found report CXR3794 with 2 images
# Found report CXR371 with 2 images
# Found report CXR3019 with 1 images
# Found report CXR2307 with 2 images
# Found report CXR2461 with 2 images
# Found report CXR1168 with 2 images
# Found report CXR2475 with 2 images
# Found report CXR2313 with 2 images
# Found report CXR3025 with 2 images
# Found report CXR1632 with 2 images
# Found report CXR1154 with 2 images
# Found report CXR3743 with 1 images
# Found report CXR2449 with 2 images
# Found report CXR3757 with 2 images
# Found report CXR1140 with 2 images
# Found report CXR1626 with 2 images
# Found report CXR3031 with 2 images
# Found report CXR1961 with 2 images
# Found report CXR3810 with 2 images
# Found report CXR3804 with 2 images
# Found report CXR239 with 2 images
# Found report CXR1975 with 3 images
# Found report CXR211 with 2 images
# Found report CXR1785 with 2 images
# Found report CXR3192 with 2 images
# Found report CXR577 with 2 images
# Found report CXR563 with 2 images
# Found report CXR3838 with 1 images
# Found report CXR3186 with 2 images
# Found report CXR2298 with 1 images
# Found report CXR1791 with 2 images
# Found report CXR205 with 2 images
# Found report CXR1949 with 3 images
# Found report CXR2273 with 2 images
# Found report CXR2515 with 1 images
# Found report CXR588 with 2 images
# Found report CXR1008 with 2 images
# Found report CXR2501 with 2 images
# Found report CXR2267 with 2 images
# Found report CXR3179 with 2 images
# Found report CXR3151 with 1 images
# Found report CXR1746 with 2 images
# Found report CXR1020 with 2 images
# Found report CXR3637 with 3 images
# Found report CXR2529 with 2 images
# Found report CXR3623 with 2 images
# Found report CXR1034 with 2 images
# Found report CXR1752 with 2 images
# Found report CXR3145 with 2 images
# Found report CXR749 with 2 images
# Found report CXR991 with 2 images
# Found report CXR985 with 1 images
# Found report CXR2918 with 2 images
# Found report CXR2930 with 3 images
# Found report CXR3390 with 3 images
# Found report CXR1587 with 2 images
# Found report CXR1593 with 2 images
# Found report CXR3384 with 2 images
# Found report CXR2924 with 2 images
# Found report CXR761 with 2 images
# Found report CXR952 with 2 images
# Found report CXR2717 with 1 images
# Found report CXR3409 with 1 images
# Found report CXR2071 with 1 images
# Found report CXR1578 with 2 images
# Found report CXR2065 with 2 images
# Found report CXR946 with 2 images
# Found report CXR3435 with 2 images
# Found report CXR1222 with 2 images
# Found report CXR1544 with 2 images
# Found report CXR3353 with 1 images
# Found report CXR3347 with 2 images
# Found report CXR2059 with 2 images
# Found report CXR1550 with 2 images
# Found report CXR1236 with 2 images
# Found report CXR3421 with 2 images
# Found report CXR1551 with 2 images
# Found report CXR2058 with 2 images
# Found report CXR3346 with 2 images
# Found report CXR3420 with 2 images
# Found report CXR1237 with 2 images
# Found report CXR1223 with 2 images
# Found report CXR3434 with 2 images
# Found report CXR3352 with 2 images
# Found report CXR1545 with 2 images
# Found report CXR947 with 2 images
# Found report CXR2702 with 2 images
# Found report CXR3408 with 2 images
# Found report CXR2716 with 2 images
# Found report CXR953 with 1 images
# Found report CXR1579 with 1 images
# Found report CXR2070 with 2 images
# Found report CXR3385 with 2 images
# Found report CXR1592 with 1 images
# Found report CXR760 with 2 images
# Found report CXR2925 with 2 images
# Found report CXR2931 with 2 images
# Found report CXR774 with 1 images
# Found report CXR1586 with 2 images
# Found report CXR3391 with 2 images
# Found report CXR2919 with 2 images
# Found report CXR984 with 3 images
# Found report CXR990 with 2 images
# Found report CXR748 with 2 images
# Found report CXR1035 with 2 images
# Found report CXR3144 with 2 images
# Found report CXR1753 with 2 images
# Found report CXR1747 with 2 images
# Found report CXR3150 with 2 images
# Found report CXR2528 with 2 images
# Found report CXR3636 with 2 images
# Found report CXR1021 with 2 images
# Found report CXR1009 with 2 images
# Found report CXR3178 with 2 images
# Found report CXR2266 with 3 images
# Found report CXR2272 with 2 images
# Found report CXR589 with 1 images
# Found report CXR2514 with 2 images
# Found report CXR3839 with 1 images
# Found report CXR562 with 2 images
# Found report CXR1948 with 2 images
# Found report CXR204 with 1 images
# Found report CXR1790 with 1 images
# Found report CXR2299 with 2 images
# Found report CXR3187 with 2 images
# Found report CXR3193 with 2 images
# Found report CXR1784 with 2 images
# Found report CXR210 with 3 images
# Found report CXR576 with 2 images
# Found report CXR3805 with 1 images
# Found report CXR1974 with 2 images
# Found report CXR238 with 2 images
# Found report CXR1960 with 2 images
# Found report CXR3811 with 2 images
# Found report CXR1141 with 2 images
# Found report CXR3756 with 2 images
# Found report CXR2448 with 2 images
# Found report CXR3030 with 2 images
# Found report CXR1627 with 2 images
# Found report CXR1633 with 3 images
# Found report CXR3024 with 2 images
# Found report CXR3742 with 2 images
# Found report CXR1155 with 1 images
# Found report CXR2474 with 1 images
# Found report CXR2312 with 2 images
# Found report CXR2306 with 2 images
# Found report CXR3018 with 2 images
# Found report CXR1169 with 1 images
# Found report CXR2460 with 2 images
# Found report CXR3795 with 2 images
# Found report CXR416 with 2 images
# Found report CXR1182 with 2 images
# Found report CXR370 with 2 images
# Found report CXR364 with 2 images
# Found report CXR1828 with 2 images
# Found report CXR1196 with 2 images
# Found report CXR402 with 1 images
# Found report CXR3959 with 2 images
# Found report CXR3781 with 2 images
# Found report CXR3971 with 3 images
# Found report CXR1800 with 2 images
# Found report CXR358 with 2 images
# Found report CXR1814 with 2 images
# Found report CXR3965 with 4 images
# Found report CXR1425 with 2 images
# Found report CXR3232 with 2 images
# Found report CXR2892 with 2 images
# Found report CXR1343 with 2 images
# Found report CXR1357 with 1 images
# Found report CXR2886 with 2 images
# Found report CXR3540 with 2 images
# Found report CXR3226 with 2 images
# Found report CXR9 with 2 images
# Found report CXR2138 with 2 images
# Found report CXR1431 with 2 images
# Found report CXR2110 with 2 images
# Found report CXR1419 with 2 images
# Found report CXR833 with 2 images
# Found report CXR73 with 1 images
# Found report CXR2676 with 2 images
# Found report CXR3568 with 2 images
# Found report CXR2662 with 2 images
# Found report CXR827 with 2 images
# Found report CXR67 with 2 images
# Found report CXR172 with 2 images
# Found report CXR1380 with 2 images
# Found report CXR614 with 2 images
# Found report CXR2851 with 2 images
# Found report CXR3597 with 2 images
# Found report CXR2689 with 2 images
# Found report CXR2845 with 2 images
# Found report CXR3583 with 2 images
# Found report CXR98 with 2 images
# Found report CXR600 with 2 images
# Found report CXR1394 with 2 images
# Found report CXR166 with 2 images
# Found report CXR628 with 2 images
# Found report CXR2879 with 2 images
# Found report CXR2822 with 2 images
# Found report CXR667 with 2 images
# Found report CXR101 with 2 images
# Found report CXR3282 with 3 images
# Found report CXR3296 with 2 images
# Found report CXR2188 with 2 images
# Found report CXR115 with 2 images
# Found report CXR1481 with 2 images
# Found report CXR673 with 1 images
# Found report CXR2836 with 2 images
# Found report CXR883 with 2 images
# Found report CXR129 with 2 images
# Found report CXR897 with 2 images
# Found report CXR1330 with 2 images
# Found report CXR3527 with 2 images
# Found report CXR2639 with 2 images
# Found report CXR3241 with 2 images
# Found report CXR1456 with 2 images
# Found report CXR1442 with 2 images
# Found report CXR3255 with 1 images
# Found report CXR3533 with 2 images
# Found report CXR28 with 2 images
# Found report CXR1324 with 2 images
# Found report CXR868 with 2 images
# Found report CXR2605 with 1 images
# Found report CXR698 with 2 images
# Found report CXR840 with 2 images
# Found report CXR2163 with 2 images
# Found report CXR2177 with 3 images
# Found report CXR3269 with 2 images
# Found report CXR14 with 2 images
# Found report CXR1318 with 2 images
# Found report CXR854 with 2 images
# Found report CXR2611 with 3 images
# Found report CXR3080 with 2 images
# Found report CXR303 with 1 images
# Found report CXR1697 with 2 images
# Found report CXR465 with 2 images
# Found report CXR471 with 2 images
# Found report CXR1683 with 2 images
# Found report CXR317 with 2 images
# Found report CXR3094 with 2 images
# Found report CXR1873 with 2 images
# Found report CXR3902 with 2 images
# Found report CXR459 with 2 images
# Found report CXR3916 with 2 images
# Found report CXR1867 with 2 images
# Found report CXR1654 with 2 images
# Found report CXR3043 with 2 images
# Found report CXR3725 with 2 images
# Found report CXR1126 with 2 images
# Found report CXR3731 with 2 images
# Found report CXR3057 with 1 images
# Found report CXR2349 with 2 images
# Found report CXR1640 with 2 images
# Found report CXR1898 with 2 images
# Found report CXR2361 with 2 images
# Found report CXR1668 with 2 images
# Found report CXR2407 with 2 images
# Found report CXR3719 with 2 images
# Found report CXR2413 with 2 images
# Found report CXR2375 with 2 images
# Found report CXR277 with 2 images
# Found report CXR511 with 2 images
# Found report CXR1085 with 2 images
# Found report CXR3692 with 2 images
# Found report CXR3686 with 2 images
# Found report CXR1091 with 2 images
# Found report CXR505 with 2 images
# Found report CXR263 with 1 images
# Found report CXR1907 with 2 images
# Found report CXR3876 with 2 images
# Found report CXR539 with 2 images
# Found report CXR3862 with 2 images
# Found report CXR1913 with 2 images
# Found report CXR1720 with 3 images
# Found report CXR2229 with 2 images
# Found report CXR3137 with 2 images
# Found report CXR3651 with 2 images
# Found report CXR3889 with 2 images
# Found report CXR1046 with 2 images
# Found report CXR1052 with 2 images
# Found report CXR3645 with 1 images
# Found report CXR3123 with 2 images
# Found report CXR1734 with 2 images
# Found report CXR2215 with 2 images
# Found report CXR288 with 2 images
# Found report CXR2573 with 1 images
# Found report CXR3679 with 2 images
# Found report CXR2567 with 2 images
# Found report CXR1708 with 2 images
# Found report CXR2201 with 1 images
# Found report CXR3490 with 2 images
# Found report CXR2956 with 2 images
# Found report CXR1287 with 2 images
# Found report CXR713 with 2 images
# Found report CXR707 with 2 images
# Found report CXR1293 with 1 images
# Found report CXR2942 with 2 images
# Found report CXR908 with 2 images
# Found report CXR1244 with 2 images
# Found report CXR3453 with 2 images
# Found report CXR2995 with 2 images
# Found report CXR3335 with 2 images
# Found report CXR1522 with 1 images
# Found report CXR1536 with 3 images
# Found report CXR3321 with 2 images
# Found report CXR2759 with 2 images
# Found report CXR2981 with 2 images
# Found report CXR1250 with 2 images
# Found report CXR2771 with 2 images
# Found report CXR934 with 2 images
# Found report CXR1278 with 2 images
# Found report CXR3309 with 2 images
# Found report CXR2017 with 2 images
# Found report CXR2003 with 2 images
# Found report CXR920 with 2 images
# Found report CXR2765 with 2 images
# Found report CXR2002 with 2 images
# Found report CXR2764 with 1 images
# Found report CXR921 with 2 images
# Found report CXR1279 with 1 images
# Found report CXR935 with 2 images
# Found report CXR2770 with 2 images
# Found report CXR2016 with 2 images
# Found report CXR3320 with 2 images
# Found report CXR1537 with 2 images
# Found report CXR2980 with 2 images
# Found report CXR3446 with 2 images
# Found report CXR2758 with 1 images
# Found report CXR2994 with 2 images
# Found report CXR3452 with 2 images
# Found report CXR1245 with 2 images
# Found report CXR909 with 2 images
# Found report CXR1523 with 3 images
# Found report CXR3334 with 2 images
# Found report CXR2943 with 2 images
# Found report CXR3485 with 2 images
# Found report CXR1292 with 2 images
# Found report CXR706 with 2 images
# Found report CXR712 with 3 images
# Found report CXR1286 with 1 images
# Found report CXR2957 with 2 images
# Found report CXR3491 with 2 images
# Found report CXR2566 with 2 images
# Found report CXR3678 with 2 images
# Found report CXR2200 with 2 images
# Found report CXR1709 with 2 images
# Found report CXR289 with 2 images
# Found report CXR2214 with 1 images
# Found report CXR2572 with 2 images
# Found report CXR3644 with 2 images
# Found report CXR1053 with 2 images
# Found report CXR1735 with 2 images
# Found report CXR3122 with 2 images
# Found report CXR3136 with 2 images
# Found report CXR2228 with 2 images
# Found report CXR1721 with 2 images
# Found report CXR1047 with 2 images
# Found report CXR3888 with 1 images
# Found report CXR3650 with 2 images
# Found report CXR3863 with 2 images
# Found report CXR538 with 2 images
# Found report CXR1912 with 2 images
# Found report CXR1906 with 2 images
# Found report CXR3877 with 2 images
# Found report CXR504 with 2 images
# Found report CXR1090 with 2 images
# Found report CXR3687 with 2 images
# Found report CXR2599 with 1 images
# Found report CXR262 with 1 images
# Found report CXR276 with 2 images
# Found report CXR3693 with 2 images
# Found report CXR1084 with 2 images
# Found report CXR510 with 3 images
# Found report CXR2412 with 2 images
# Found report CXR2374 with 2 images
# Found report CXR1669 with 2 images
# Found report CXR2360 with 2 images
# Found report CXR3718 with 1 images
# Found report CXR2406 with 2 images
# Found report CXR3730 with 2 images
# Found report CXR1899 with 2 images
# Found report CXR1641 with 2 images
# Found report CXR2348 with 2 images
# Found report CXR3056 with 1 images
# Found report CXR3042 with 1 images
# Found report CXR1655 with 2 images
# Found report CXR1133 with 2 images
# Found report CXR3724 with 2 images
# Found report CXR3917 with 2 images
# Found report CXR1866 with 2 images
# Found report CXR1872 with 1 images
# Found report CXR458 with 2 images
# Found report CXR3903 with 2 images
# Found report CXR470 with 2 images
# Found report CXR3095 with 2 images
# Found report CXR316 with 2 images
# Found report CXR1682 with 2 images
# Found report CXR1696 with 2 images
# Found report CXR302 with 1 images
# Found report CXR3081 with 2 images
# Found report CXR464 with 2 images
# Found report CXR3268 with 1 images
# Found report CXR2176 with 2 images
# Found report CXR2610 with 2 images
# Found report CXR855 with 2 images
# Found report CXR1319 with 2 images
# Found report CXR15 with 2 images
# Found report CXR841 with 2 images
# Found report CXR699 with 2 images
# Found report CXR2604 with 2 images
# Found report CXR2162 with 2 images
# Found report CXR3254 with 2 images
# Found report CXR1443 with 2 images
# Found report CXR869 with 2 images
# Found report CXR29 with 2 images
# Found report CXR3532 with 3 images
# Found report CXR2638 with 2 images
# Found report CXR3526 with 2 images
# Found report CXR1331 with 1 images
# Found report CXR1457 with 1 images
# Found report CXR3240 with 2 images
# Found report CXR128 with 2 images
# Found report CXR896 with 3 images
# Found report CXR882 with 2 images
# Found report CXR1480 with 2 images
# Found report CXR114 with 2 images
# Found report CXR2189 with 2 images
# Found report CXR3297 with 2 images
# Found report CXR2837 with 2 images
# Found report CXR672 with 2 images
# Found report CXR666 with 2 images
# Found report CXR3283 with 3 images
# Found report CXR100 with 2 images
# Found report CXR1494 with 2 images
# Found report CXR670 with 2 images
# Found report CXR2835 with 3 images
# Found report CXR116 with 2 images
# Found report CXR1482 with 1 images
# Found report CXR1496 with 2 images
# Found report CXR102 with 2 images
# Found report CXR3281 with 3 images
# Found report CXR2821 with 2 images
# Found report CXR664 with 2 images
# Found report CXR2809 with 2 images
# Found report CXR894 with 2 images
# Found report CXR880 with 2 images
# Found report CXR658 with 2 images
# Found report CXR3530 with 2 images
# Found report CXR1327 with 2 images
# Found report CXR1441 with 2 images
# Found report CXR2148 with 2 images
# Found report CXR3256 with 2 images
# Found report CXR3242 with 2 images
# Found report CXR1455 with 2 images
# Found report CXR1333 with 2 images
# Found report CXR3524 with 2 images
# Found report CXR17 with 2 images
# Found report CXR857 with 2 images
# Found report CXR2612 with 2 images
# Found report CXR2174 with 2 images
# Found report CXR1469 with 2 images
# Found report CXR2160 with 2 images
# Found report CXR3518 with 2 images
# Found report CXR2606 with 1 images
# Found report CXR843 with 2 images
# Found report CXR1680 with 2 images
# Found report CXR314 with 2 images
# Found report CXR2389 with 2 images
# Found report CXR3097 with 1 images
# Found report CXR3929 with 2 images
# Found report CXR472 with 2 images
# Found report CXR466 with 2 images
# Found report CXR3083 with 2 images
# Found report CXR300 with 2 images
# Found report CXR1694 with 2 images
# Found report CXR1864 with 2 images
# Found report CXR328 with 2 images
# Found report CXR3915 with 2 images
# Found report CXR3901 with 2 images
# Found report CXR1870 with 2 images
# Found report CXR3054 with 2 images
# Found report CXR1643 with 3 images
# Found report CXR1125 with 2 images
# Found report CXR3732 with 2 images
# Found report CXR2438 with 2 images
# Found report CXR3726 with 2 images
# Found report CXR1131 with 2 images
# Found report CXR1657 with 2 images
# Found report CXR3040 with 1 images
# Found report CXR3068 with 1 images
# Found report CXR2376 with 2 images
# Found report CXR2410 with 2 images
# Found report CXR1119 with 2 images
# Found report CXR499 with 2 images
# Found report CXR2404 with 2 images
# Found report CXR2362 with 2 images
# Found report CXR260 with 2 images
# Found report CXR3685 with 2 images
# Found report CXR1092 with 2 images
# Found report CXR506 with 2 images
# Found report CXR512 with 1 images
# Found report CXR1086 with 2 images
# Found report CXR3849 with 2 images
# Found report CXR3691 with 2 images
# Found report CXR274 with 2 images
# Found report CXR1938 with 2 images
# Found report CXR1910 with 3 images
# Found report CXR3861 with 2 images
# Found report CXR3875 with 1 images
# Found report CXR248 with 2 images
# Found report CXR1904 with 2 images
# Found report CXR3120 with 2 images
# Found report CXR1737 with 2 images
# Found report CXR1051 with 2 images
# Found report CXR3646 with 2 images
# Found report CXR2558 with 2 images
# Found report CXR3652 with 2 images
# Found report CXR1045 with 2 images
# Found report CXR1723 with 2 images
# Found report CXR3134 with 2 images
# Found report CXR2202 with 2 images
# Found report CXR2564 with 2 images
# Found report CXR1079 with 2 images
# Found report CXR2570 with 2 images
# Found report CXR2216 with 2 images
# Found report CXR3108 with 3 images
# Found report CXR704 with 2 images
# Found report CXR1290 with 1 images
# Found report CXR3487 with 2 images
# Found report CXR2941 with 2 images
# Found report CXR2799 with 2 images
# Found report CXR3493 with 2 images
# Found report CXR2955 with 2 images
# Found report CXR1284 with 1 images
# Found report CXR710 with 2 images
# Found report CXR738 with 2 images
# Found report CXR2969 with 2 images
# Found report CXR3444 with 3 images
# Found report CXR2982 with 2 images
# Found report CXR1253 with 2 images
# Found report CXR1535 with 2 images
# Found report CXR3322 with 2 images
# Found report CXR3336 with 2 images
# Found report CXR2028 with 2 images
# Found report CXR1521 with 3 images
# Found report CXR3450 with 2 images
# Found report CXR2996 with 2 images
# Found report CXR923 with 2 images
# Found report CXR2766 with 2 images
# Found report CXR3478 with 2 images
# Found report CXR2000 with 2 images
# Found report CXR1509 with 2 images
# Found report CXR2014 with 2 images
# Found report CXR2772 with 2 images
# Found report CXR937 with 2 images
# Found report CXR2015 with 2 images
# Found report CXR936 with 1 images
# Found report CXR2773 with 2 images
# Found report CXR3479 with 2 images
# Found report CXR2767 with 2 images
# Found report CXR922 with 2 images
# Found report CXR1508 with 2 images
# Found report CXR2001 with 2 images
# Found report CXR1520 with 2 images
# Found report CXR2029 with 2 images
# Found report CXR3337 with 2 images
# Found report CXR2997 with 2 images
# Found report CXR3451 with 2 images
# Found report CXR1246 with 2 images
# Found report CXR1252 with 2 images
# Found report CXR2983 with 2 images
# Found report CXR3445 with 2 images
# Found report CXR3323 with 1 images
# Found report CXR1534 with 2 images
# Found report CXR2968 with 2 images
# Found report CXR739 with 2 images
# Found report CXR711 with 1 images
# Found report CXR1285 with 3 images
# Found report CXR2954 with 2 images
# Found report CXR3492 with 2 images
# Found report CXR2798 with 2 images
# Found report CXR2940 with 2 images
# Found report CXR3486 with 2 images
# Found report CXR1291 with 2 images
# Found report CXR705 with 2 images
# Found report CXR2571 with 1 images
# Found report CXR1078 with 2 images
# Found report CXR3109 with 2 images
# Found report CXR2217 with 2 images
# Found report CXR2203 with 2 images
# Found report CXR2565 with 2 images
# Found report CXR1044 with 2 images
# Found report CXR3653 with 2 images
# Found report CXR3135 with 2 images
# Found report CXR1722 with 1 images
# Found report CXR1736 with 2 images
# Found report CXR3121 with 2 images
# Found report CXR2559 with 2 images
# Found report CXR3647 with 2 images
# Found report CXR1050 with 2 images
# Found report CXR3874 with 2 images
# ...
# Found report CXR3991 with 2 images
# Found report CXR3749 with 2 images
# Found report CXR2443 with 2 images
# Found report CXR3985 with 2 images
# Found report CXR2325 with 2 images
# Found report CXR3013 with 2 images
# Found report CXR390 with 2 images
# Found report CXR1604 with 2 images
# Found report CXR1162 with 2 images
# Found report CXR3775 with 2 images
# Found report CXR3761 with 2 images
# Found report CXR1176 with 2 images
# Found report CXR1610 with 3 images
# Found report CXR384 with 1 images
# Found report CXR2319 with 2 images
# Found report CXR3198 with 2 images
# Found report CXR2286 with 2 images
# Found report CXR1957 with 2 images
# Found report CXR3826 with 2 images
# Found report CXR3832 with 2 images
# Found report CXR569 with 2 images
# Found report CXR1943 with 2 images
# Found report CXR2292 with 2 images
# Found report CXR227 with 3 images
# Found report CXR541 with 1 images
# Found report CXR555 with 1 images
# Found report CXR233 with 3 images
# Found report CXR1994 with 2 images
# Found report CXR2245 with 2 images
# Found report CXR2523 with 2 images
# Found report CXR3629 with 2 images
# Found report CXR2537 with 2 images
# Found report CXR2251 with 1 images
# Found report CXR1980 with 2 images
# Found report CXR1758 with 2 images
# Found report CXR2279 with 2 images
# Found report CXR3167 with 2 images
# Found report CXR1770 with 2 images
# Found report CXR582 with 2 images
# Found report CXR1016 with 2 images
# Found report CXR3601 with 2 images
# Found report CXR3615 with 2 images
# Found report CXR1002 with 2 images
# Found report CXR596 with 2 images
# Found report CXR1764 with 1 images
# Found report CXR3173 with 2 images
# Found report CXR2084 with 4 images
# Found report CXR2090 with 2 images
# Found report CXR1599 with 2 images
# Found report CXR743 with 2 images
# Found report CXR2906 with 2 images
# Found report CXR757 with 2 images
# Found report CXR964 with 2 images
# Found report CXR1228 with 3 images
# Found report CXR2721 with 2 images
# Found report CXR3359 with 4 images
# Found report CXR2047 with 2 images
# Found report CXR2053 with 2 images
# Found report CXR2735 with 2 images
# Found report CXR970 with 2 images
# Found report CXR3403 with 2 images
# Found report CXR958 with 2 images
# Found report CXR1214 with 2 images
# Found report CXR780 with 2 images
# Found report CXR1572 with 2 images
# Found report CXR3365 with 2 images
# Found report CXR3371 with 2 images
# Found report CXR1566 with 1 images
# Found report CXR794 with 2 images
# Found report CXR1200 with 2 images
# Found report CXR2709 with 2 images
# Found report CXR3417 with 2 images
# Found report CXR1567 with 2 images
# Found report CXR3370 with 2 images
# Found report CXR3416 with 2 images
# Found report CXR2708 with 2 images
# Found report CXR795 with 2 images
# Found report CXR781 with 2 images
# Found report CXR959 with 2 images
# Found report CXR3402 with 2 images
# Found report CXR3364 with 2 images
# Found report CXR1573 with 2 images
# Found report CXR2052 with 2 images
# Found report CXR971 with 2 images
# Found report CXR2734 with 2 images
# Found report CXR2720 with 2 images
# Found report CXR1229 with 2 images
# Found report CXR965 with 2 images
# Found report CXR2046 with 2 images
# Found report CXR3358 with 2 images
# Found report CXR756 with 3 images
# Found report CXR742 with 2 images
# Found report CXR1598 with 2 images
# Found report CXR2091 with 2 images
# Found report CXR2085 with 1 images
# Found report CXR597 with 1 images
# Found report CXR1003 with 1 images
# Found report CXR3614 with 2 images
# Found report CXR3172 with 2 images
# Found report CXR1765 with 2 images
# Found report CXR1771 with 2 images
# Found report CXR3166 with 2 images
# Found report CXR2278 with 2 images
# Found report CXR3600 with 2 images
# Found report CXR1017 with 2 images
# Found report CXR583 with 2 images
# Found report CXR2536 with 2 images
# Found report CXR3628 with 2 images
# Found report CXR1759 with 2 images
# Found report CXR1981 with 2 images
# Found report CXR2250 with 1 images
# Found report CXR2244 with 2 images
# Found report CXR1995 with 2 images
# Found report CXR2522 with 1 images
# Found report CXR554 with 2 images
# Found report CXR226 with 2 images
# Found report CXR540 with 2 images
# Found report CXR568 with 2 images
# Found report CXR3833 with 2 images
# Found report CXR2293 with 2 images
# Found report CXR1942 with 1 images
# Found report CXR1956 with 2 images
# Found report CXR2287 with 2 images
# Found report CXR3199 with 1 images
# Found report CXR3827 with 2 images
# Found report CXR1177 with 2 images
# Found report CXR3760 with 2 images
# Found report CXR2318 with 2 images
# Found report CXR3006 with 1 images
# Found report CXR385 with 2 images
# Found report CXR1605 with 1 images
# Found report CXR391 with 2 images
# Found report CXR3012 with 2 images
# Found report CXR3774 with 2 images
# Found report CXR1163 with 2 images
# Found report CXR3984 with 2 images
# Found report CXR2442 with 2 images
# Found report CXR2324 with 2 images
# Found report CXR2330 with 1 images
# Found report CXR1639 with 2 images
# Found report CXR3748 with 2 images
# Found report CXR2456 with 2 images
# Found report CXR420 with 2 images
# Found report CXR346 with 3 images
# Found report CXR352 with 2 images
# Found report CXR434 with 1 images
# Found report CXR1188 with 2 images
# Found report CXR3947 with 2 images
# Found report CXR2481 with 1 images
# Found report CXR1836 with 2 images
# Found report CXR1822 with 2 images
# Found report CXR3953 with 2 images
# Found report CXR2495 with 2 images
# Found report CXR408 with 2 images
# Found report CXR1413 with 2 images
# Found report CXR187 with 2 images
# Found report CXR3204 with 2 images
# Found report CXR3562 with 2 images
# Found report CXR839 with 2 images
# Found report CXR79 with 2 images
# Found report CXR1375 with 3 images
# Found report CXR1361 with 2 images
# Found report CXR2668 with 2 images
# Found report CXR3576 with 2 images
# Found report CXR3210 with 1 images
# Found report CXR193 with 2 images
# Found report CXR1407 with 2 images
# Found report CXR3238 with 2 images
# Found report CXR2126 with 2 images
# Found report CXR805 with 2 images
# Found report CXR45 with 1 images
# Found report CXR1349 with 2 images
# Found report CXR2640 with 1 images
# Found report CXR2898 with 3 images
# Found report CXR2654 with 2 images
# Found report CXR811 with 2 images
# Found report CXR51 with 2 images
# Found report CXR3 with 2 images
# Found report CXR2132 with 2 images
# Found report CXR144 with 1 images
# Found report CXR622 with 2 images
# Found report CXR2867 with 2 images
# Found report CXR2873 with 2 images
# Found report CXR636 with 2 images
# Found report CXR150 with 2 images
# Found report CXR178 with 1 images
# Found report CXR2683 with 2 images
# Found report CXR86 with 3 images
# Found report CXR92 with 2 images
# Found report CXR3589 with 2 images
# Found report CXR2697 with 1 images
# Found report CXR1388 with 2 images
# Found report CXR84 with 2 images
# Found report CXR2681 with 2 images
# Found report CXR2859 with 2 images
# Found report CXR2695 with 2 images
# Found report CXR608 with 2 images
# Found report CXR90 with 2 images
# Found report CXR2865 with 2 images
# Found report CXR620 with 2 images
# Found report CXR146 with 3 images
# Found report CXR152 with 2 images
# Found report CXR634 with 2 images
# Found report CXR2871 with 2 images
# Found report CXR2642 with 2 images
# Found report CXR47 with 2 images
# Found report CXR2124 with 2 images
# Found report CXR2130 with 2 images
# Found report CXR1 with 2 images
# Found report CXR1439 with 2 images
# Found report CXR53 with 2 images
# Found report CXR813 with 2 images
# Found report CXR3548 with 2 images
# Found report CXR2656 with 1 images
# Found report CXR1377 with 2 images
# Found report CXR3560 with 2 images
# Found report CXR2118 with 2 images
# Found report CXR3206 with 2 images
# Found report CXR185 with 2 images
# Found report CXR1411 with 2 images
# Found report CXR1405 with 2 images
# Found report CXR191 with 2 images
# Found report CXR3212 with 2 images
# Found report CXR3574 with 2 images
# Found report CXR1363 with 2 images
# Found report CXR1834 with 2 images
# Found report CXR378 with 2 images
# Found report CXR2483 with 2 images
# Found report CXR3945 with 2 images
# Found report CXR3789 with 2 images
# Found report CXR2497 with 2 images
# Found report CXR3951 with 2 images
# Found report CXR1820 with 2 images
# Found report CXR1808 with 2 images
# Found report CXR344 with 2 images
# Found report CXR422 with 2 images
# Found report CXR3979 with 2 images
# Found report CXR436 with 2 images
# Found report CXR350 with 2 images
# Found report CXR3038 with 2 images
# Found report CXR2326 with 2 images
# Found report CXR1149 with 2 images
# Found report CXR2440 with 2 images
# Found report CXR3986 with 3 images
# Found report CXR2454 with 2 images
# Found report CXR3992 with 2 images
# Found report CXR2332 with 2 images
# Found report CXR387 with 2 images
# Found report CXR3004 with 2 images
# Found report CXR3762 with 2 images
# Found report CXR1175 with 2 images
# Found report CXR1161 with 2 images
# Found report CXR2468 with 2 images
# Found report CXR3776 with 1 images
# Found report CXR3010 with 2 images
# Found report CXR393 with 2 images
# Found report CXR1607 with 1 images
# Found report CXR1798 with 2 images
# Found report CXR1940 with 2 images
# Found report CXR2291 with 2 images
# Found report CXR3831 with 2 images
# Found report CXR3825 with 2 images
# Found report CXR2285 with 2 images
# Found report CXR218 with 2 images
# Found report CXR1954 with 2 images
# Found report CXR230 with 2 images
# Found report CXR556 with 2 images
# Found report CXR3819 with 3 images
# Found report CXR542 with 1 images
# Found report CXR224 with 2 images
# Found report CXR1968 with 2 images
# Found report CXR2252 with 2 images
# Found report CXR1983 with 2 images
# Found report CXR2520 with 2 images
# Found report CXR1029 with 1 images
# Found report CXR1997 with 2 images
# Found report CXR2246 with 2 images
# Found report CXR3158 with 2 images
# Found report CXR1767 with 2 images
# Found report CXR3170 with 2 images
# Found report CXR3616 with 2 images
# Found report CXR1001 with 2 images
# Found report CXR595 with 2 images
# Found report CXR581 with 2 images
# Found report CXR1015 with 4 images
# Found report CXR3602 with 2 images
# Found report CXR3164 with 2 images
# Found report CXR1773 with 2 images
# Found report CXR768 with 2 images
# Found report CXR2093 with 2 images
# Found report CXR2087 with 3 images
# Found report CXR3399 with 1 images
# Found report CXR2939 with 2 images
# Found report CXR2911 with 2 images
# Found report CXR754 with 2 images
# Found report CXR740 with 1 images
# Found report CXR998 with 2 images
# Found report CXR2905 with 1 images
# Found report CXR3428 with 2 images
# Found report CXR973 with 2 images
# Found report CXR1559 with 2 images
# Found report CXR2050 with 2 images
# Found report CXR2044 with 2 images
# Found report CXR967 with 2 images
# Found report CXR2722 with 2 images
# Found report CXR797 with 2 images
# Found report CXR1203 with 2 images
# Found report CXR3414 with 2 images
# Found report CXR3372 with 2 images
# Found report CXR1565 with 2 images
# Found report CXR1571 with 1 images
# Found report CXR3366 with 2 images
# Found report CXR2078 with 2 images
# Found report CXR3400 with 2 images
# Found report CXR1217 with 2 images
# Found report CXR783 with 2 images
# Found report CXR2079 with 2 images
# Found report CXR3367 with 2 images
# Found report CXR1570 with 2 images
# Found report CXR782 with 2 images
# Found report CXR1216 with 1 images
# Found report CXR3401 with 2 images
# Found report CXR3415 with 2 images
# Found report CXR1202 with 2 images
# Found report CXR796 with 2 images
# Found report CXR1564 with 2 images
# Found report CXR3373 with 2 images
# Found report CXR2045 with 2 images
# Found report CXR2723 with 2 images
# Found report CXR966 with 2 images
# Found report CXR972 with 2 images
# Found report CXR3429 with 2 images
# Found report CXR2737 with 1 images
# Found report CXR1558 with 2 images
# Found report CXR2904 with 2 images
# Found report CXR999 with 3 images
# Found report CXR741 with 1 images
# Found report CXR755 with 2 images
# Found report CXR2910 with 2 images
# Found report CXR3398 with 2 images
# Found report CXR2086 with 2 images
# Found report CXR2938 with 2 images
# Found report CXR769 with 2 images
# Found report CXR2092 with 2 images
# Found report CXR3603 with 2 images
# Found report CXR1014 with 2 images
# Found report CXR580 with 2 images
# Found report CXR3165 with 2 images
# Found report CXR3171 with 2 images
# Found report CXR1766 with 2 images
# Found report CXR594 with 2 images
# Found report CXR1000 with 3 images
# Found report CXR2509 with 2 images
# Found report CXR3617 with 2 images
# Found report CXR1028 with 2 images
# Found report CXR3159 with 2 images
# Found report CXR2247 with 2 images
# Found report CXR1982 with 2 images
# Found report CXR2253 with 2 images
# Found report CXR2535 with 1 images
# Found report CXR543 with 2 images
# Found report CXR3818 with 2 images
# Found report CXR1969 with 1 images
# Found report CXR225 with 2 images
# Found report CXR557 with 2 images
# Found report CXR3824 with 1 images
# Found report CXR219 with 2 images
# Found report CXR2290 with 2 images
# Found report CXR1941 with 1 images
# Found report CXR1799 with 2 images
# Found report CXR3830 with 2 images
# Found report CXR3777 with 2 images
# Found report CXR2469 with 2 images
# Found report CXR1160 with 2 images
# Found report CXR1606 with 1 images
# Found report CXR392 with 2 images
# Found report CXR3011 with 2 images
# Found report CXR3005 with 1 images
# Found report CXR386 with 2 images
# Found report CXR1612 with 1 images
# Found report CXR1174 with 2 images
# Found report CXR3763 with 2 images
# Found report CXR3993 with 2 images
# Found report CXR2455 with 2 images
# Found report CXR2333 with 1 images
# Found report CXR2327 with 2 images
# Found report CXR3039 with 2 images
# Found report CXR3987 with 2 images
# Found report CXR2441 with 2 images
# Found report CXR1148 with 2 images
# Found report CXR437 with 2 images
# Found report CXR351 with 2 images
# Found report CXR345 with 2 images
# Found report CXR1809 with 2 images
# Found report CXR3978 with 2 images
# Found report CXR423 with 3 images
# Found report CXR3950 with 1 images
# Found report CXR2496 with 1 images
# Found report CXR1821 with 2 images
# Found report CXR379 with 2 images
# Found report CXR1835 with 2 images
# Found report CXR3944 with 2 images
# Found report CXR2482 with 2 images
# Found report CXR3213 with 1 images
# Found report CXR190 with 2 images
# Found report CXR1404 with 2 images
# Found report CXR1362 with 2 images
# Found report CXR3575 with 2 images
# Found report CXR3561 with 2 images
# Found report CXR1376 with 2 images
# Found report CXR1410 with 2 images
# Found report CXR184 with 2 images
# Found report CXR3207 with 2 images
# Found report CXR2119 with 2 images
# Found report CXR1438 with 2 images
# Found report CXR2131 with 2 images
# Found report CXR2657 with 2 images
# Found report CXR3549 with 3 images
# Found report CXR812 with 2 images
# Found report CXR52 with 2 images
# Found report CXR806 with 2 images
# Found report CXR46 with 2 images
# Found report CXR2643 with 2 images
# Found report CXR2125 with 2 images
# Found report CXR153 with 2 images
# Found report CXR2870 with 2 images
# Found report CXR635 with 2 images
# Found report CXR621 with 2 images
# Found report CXR2864 with 1 images
# Found report CXR147 with 1 images
# Found report CXR91 with 1 images
# Found report CXR609 with 2 images
# Found report CXR2694 with 2 images
# Found report CXR2858 with 3 images
# Found report CXR2680 with 3 images
# Found report CXR85 with 2 images
# Found report CXR1389 with 3 images
# Mapping saved to mapping_results.csv
# Found 7470 out of 7470 images (100.00%)
# Sample matched PNG paths:
#   /Users/nuthankishoremaddineni/Downloads/NLMCXR_png/CXR162_IM-0401-1001.png
#   /Users/nuthankishoremaddineni/Downloads/NLMCXR_png/CXR162_IM-0401-2001.png
#   /Users/nuthankishoremaddineni/Downloads/NLMCXR_png/CXR1390_IM-0249-1001.png
#   /Users/nuthankishoremaddineni/Downloads/NLMCXR_png/CXR1390_IM-0249-2001.png
#   /Users/nuthankishoremaddineni/Downloads/NLMCXR_png/CXR604_IM-2193-1001.png
# Verified mapping saved to verified_mapping_results.csv
#
# Mapping Statistics:
# Total reports: 3851
# Total images: 7470
# Average images per report: 1.94
#
# Reports with multiple images: 3405
# Top 5 reports with the most images:
# ReportID
# CXR1303    5
# CXR3566    4
# CXR1525    4
# CXR2097    4
# CXR2560    4
# Name: count, dtype: int64
