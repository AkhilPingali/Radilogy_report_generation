# %%
print("hi")
# Out:
# hi

# %%
import tensorflow as tf
print("hi",tf.test.gpu_device_name())  # Check if GPU is available
# Out:
# hi /device:GPU:0
# 2025-02-28 09:11:17.416099: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2025-02-28 09:11:17.416144: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-02-28 09:11:17.416150: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-02-28 09:11:17.416182: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-02-28 09:11:17.416191: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import tensorflow as tf

if tf.config.list_physical_devices('GPU'):
    print("✅ GPU is available:", tf.test.gpu_device_name())
else:
    print("❌ No GPU found. Using CPU.")
# Out:
# ✅ GPU is available: /device:GPU:0
# 2025-02-28 09:12:48.891050: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-02-28 09:12:48.891102: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import tensorflow as tf
import time

# Create large random matrices
X = tf.random.normal((10000, 1000))
Y = tf.random.normal((1000, 5000))

# Measure computation time
start = time.time()
Z = tf.matmul(X, Y)  # GPU-intensive operation
end = time.time()

print(f"Computation time: {end - start:.2f} seconds")
# Out:
# 2025-02-28 09:12:55.140514: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-02-28 09:12:55.140561: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Computation time: 0.14 seconds

# %%
tf.debugging.set_log_device_placement(True)

# Run a simple operation
X = tf.constant([[1.0, 2.0, 3.0]])
Y = tf.constant([[4.0, 5.0, 6.0]])
Z = tf.matmul(X, tf.transpose(Y))

print(Z)
# Out:
# tf.Tensor([[32.]], shape=(1, 1), dtype=float32)

# %%
import tensorflow as tf

# Ensure memory settings are applied before TensorFlow initializes the GPU
tf.keras.backend.clear_session()

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Set before initialization
        print("✅ GPU memory growth enabled.")
    except RuntimeError as e:
        print(f"⚠️ Error setting memory growth: {e}")
# Out:
# ✅ GPU memory growth enabled.

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from glob import glob
import matplotlib.pyplot as plt
import cv2

# 1. Define parameters
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 20
LEARNING_RATE = 1e-4

# 2. Create the CheXNet model architecture
def create_chexnet(input_shape=(224, 224, 3), classes=14):
    base_model = DenseNet121(
        include_top=False,
        weights=None,
        input_shape=input_shape
    )
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    predictions = Dense(classes, activation='sigmoid')(x)
    
    model = Model(inputs=base_model.input, outputs=predictions)
    return model

# Create the model
model = create_chexnet()

# 3. Load pre-trained weights
weights_path = '/Users/nuthankishoremaddineni/Desktop/Radilogy_report_generation/weights.h5'
try:
    model.load_weights(weights_path)
    print("✅ Weights loaded successfully!")
except Exception as e:
    print(f"❌ Error loading weights: {e}")

# 4. Preprocess a sample image to check if our preprocessing works
def preprocess_image(image_path):
    # Read image
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Could not read image: {image_path}")
    
    # Resize
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    
    # Convert to 3 channels by stacking
    img = np.stack([img, img, img], axis=-1)
    
    # Normalize
    img = img / 255.0
    
    return img

# Try preprocessing a sample image and print its shape
# Replace with a path to one of your X-ray images
sample_image_path = '/Users/nuthankishoremaddineni/Desktop/Radiology_Data/NLMCXR_png/CXR1_1_IM-0001-4001.png'
try:
    processed_img = preprocess_image(sample_image_path)
    print(f"Processed image shape: {processed_img.shape}")
    
    # Visualize to verify
    plt.imshow(processed_img)
    plt.title("Preprocessed X-ray Image")
    plt.axis('off')
    plt.show()
except Exception as e:
    print(f"❌ Error preprocessing sample image: {e}")

# 5. Data preparation

def prepare_dataset(image_dir, label_mapping=None):
    """
    Prepare dataset from a directory of images.
    
    Args:
        image_dir: Directory containing images
        label_mapping: Function to extract labels from filenames or paths
        
    Returns:
        DataFrame with image paths and labels
    """
    image_paths = []
    for ext in ['*.png', '*.jpg', '*.jpeg', '*.tif', '*.tiff']:
        image_paths.extend(glob(os.path.join(image_dir, ext)))
    
    print(f"Found {len(image_paths)} images")
    
    if not image_paths:
        raise ValueError(f"No images found in {image_dir}")
    
    # For demonstration, assign random labels (0 or 1) for binary classification
    # Replace this with your actual label extraction logic
    if label_mapping is None:
        # Default random labels for testing
        labels = np.random.randint(0, 2, size=len(image_paths))
    else:
        labels = [label_mapping(path) for path in image_paths]
    
    return pd.DataFrame({'image_path': image_paths, 'label': labels})

# Replace with your image directory
image_dir = '/Users/nuthankishoremaddineni/Desktop/Radiology_Data/NLMCXR_png'

# Define your label mapping function
def get_label(image_path):
    # This is an example - implement your own logic based on your dataset
    if 'normal' in image_path.lower():
        return 0  # Normal
    else:
        return 1  # Abnormal
    
# Create dataset
try:
    df = prepare_dataset(image_dir, label_mapping=get_label)
    print(f"Dataset created with {len(df)} images")
    print(df.head())
except Exception as e:
    print(f"❌ Error creating dataset: {e}")

# Split into train and validation
train_df, valid_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df['label'])
print(f"Train: {len(train_df)}, Validation: {len(valid_df)}")

# 6. Custom data generator that properly handles grayscale to RGB conversion
from tensorflow.keras.utils import Sequence

# Replace the XrayDataGenerator class with this Sequence-based implementation
class XrayDataGenerator(Sequence):
    def __init__(self, dataframe, batch_size=32, img_size=224, shuffle=True, augment=False, num_classes=14):
        self.dataframe = dataframe.copy()
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.augment = augment
        self.num_classes = num_classes
        self.n = len(self.dataframe)
        self.indexes = np.arange(self.n)
        if self.shuffle:
            np.random.shuffle(self.indexes)
        
        # Define augmentation generator
        if self.augment:
            self.augmenter = ImageDataGenerator(
                rotation_range=15,
                width_shift_range=0.1,
                height_shift_range=0.1,
                shear_range=0.1,
                zoom_range=0.1,
                horizontal_flip=True,
                fill_mode='nearest'
            )
        else:
            self.augmenter = None
    
    def __len__(self):
        return int(np.ceil(self.n / self.batch_size))
    
    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)
    
    def __getitem__(self, idx):
        batch_indexes = self.indexes[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_df = self.dataframe.iloc[batch_indexes]
        
        batch_x = []
        batch_y = []
        
        for _, row in batch_df.iterrows():
            try:
                # Load and preprocess image
                img = cv2.imread(row['image_path'], cv2.IMREAD_GRAYSCALE)
                if img is None:
                    print(f"Warning: Could not read {row['image_path']}")
                    continue
                
                # Resize
                img = cv2.resize(img, (self.img_size, self.img_size))
                
                # Convert to RGB by repeating the channel
                img = np.stack([img, img, img], axis=-1)
                
                # Normalize
                img = img / 255.0
                
                # Apply augmentation if needed
                if self.augment and self.augmenter:
                    img = self.augmenter.random_transform(img)
                
                batch_x.append(img)

                # Convert label to one-hot encoding (Multi-label classification)
                label = np.zeros(self.num_classes)  # Assuming 14 classes
                label[row['label']] = 1  # Assuming 'label' column contains indices (0-13)
                batch_y.append(label)
            except Exception as e:
                print(f"Error processing {row['image_path']}: {e}")
        
        if not batch_x:
            print("Warning: Empty batch created")
            return np.zeros((1, self.img_size, self.img_size, 3)), np.zeros((1, self.num_classes))
        
        return np.array(batch_x), np.array(batch_y)



# Create generators
train_generator = XrayDataGenerator(train_df, batch_size=BATCH_SIZE, img_size=IMG_SIZE, augment=True)
valid_generator = XrayDataGenerator(valid_df, batch_size=BATCH_SIZE, img_size=IMG_SIZE, augment=False)

# 7. Test data generator
def test_generator(generator):
    x_batch, y_batch = generator[0]
    print(f"Batch x shape: {x_batch.shape}")
    print(f"Batch y shape: {y_batch.shape}")
    
    # Plot a sample
    plt.figure(figsize=(10, 4))
    for i in range(min(3, len(x_batch))):
        plt.subplot(1, 3, i+1)
        plt.imshow(x_batch[i])
        plt.title(f"Label: {y_batch[i]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

try:
    test_generator(train_generator)
    print("✅ Data generator test successful!")
except Exception as e:
    print(f"❌ Error testing data generator: {e}")

# 8. Fine-tuning setup
# Freeze early layers to preserve learned features
for layer in model.layers[:-4]:  # Freeze all but the last 4 layers
    layer.trainable = False

# 9. Compile the model
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',  # Adjust based on your task (binary vs multi-label)
    metrics=['accuracy', tf.keras.metrics.AUC()]
)

# 10. Callbacks for training
checkpoint = ModelCheckpoint(
    'chexnet_finetuned.h5',
    monitor='val_auc',
    verbose=1,
    save_best_only=True,
    mode='max'
)

early_stopping = EarlyStopping(
    monitor='val_auc',
    patience=5,
    verbose=1,
    mode='max'
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_auc',
    factor=0.2,
    patience=3,
    verbose=1,
    mode='max',
    min_lr=1e-6
)

callbacks = [checkpoint, early_stopping, reduce_lr]
x_batch, y_batch = train_generator[0]
print(f"Batch image shape: {x_batch.shape}")  # Expected: (batch_size, 224, 224, 3)
print(f"Batch label shape: {y_batch.shape}")  # Expected: (batch_size, 14)


# 11. Train the model
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=valid_generator,
    callbacks=callbacks,
    verbose=1
)

# 12. Evaluate the model
evaluation = model.evaluate(valid_generator)
print(f"Validation Loss: {evaluation[0]}")
print(f"Validation Accuracy: {evaluation[1]}")
print(f"Validation AUC: {evaluation[2]}")

# 13. Save the fine-tuned model
model.save('chexnet_indiana_finetuned.h5')

# 14. Plot training history
def plot_training_history(history):
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper right')
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

plot_training_history(history)
# Out:
# 2025-02-28 09:26:52.731657: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2025-02-28 09:26:52.731684: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-02-28 09:26:52.731688: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-02-28 09:26:52.731858: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-02-28 09:26:52.731872: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ✅ Weights loaded successfully!
# Processed image shape: (224, 224, 3)
# Found 7470 images
# Dataset created with 7470 images
# ...

# %%
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.models import Model
import numpy as np
import cv2
import os

def load_chexnet_feature_extractor():
    # Optionally, set weights=None if you only want to use your custom weights
    base_model = DenseNet121(weights=None, include_top=False, input_shape=(224, 224, 3))
    
    weights_path = '/Users/nuthankishoremaddineni/Desktop/Radilogy_report_generation/weights.h5'
    try:
        # Load your custom CheXNet weights
        base_model.load_weights(weights_path, by_name=True, skip_mismatch=True)
        print("✅ Weights loaded successfully!")
    except Exception as e:
        print(f"❌ Error loading weights: {e}")
    
    # Add a Global Average Pooling layer for feature extraction
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    feature_extractor = Model(inputs=base_model.input, outputs=x)
    return feature_extractor

# Initialize feature extractor model
feature_extractor = load_chexnet_feature_extractor()

# Print the model summary
feature_extractor.summary()
# Out:
# ✅ Weights loaded successfully!
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_6    │ (None, 230, 230,  │          0 │ input_layer_3[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,408 │ zero_padding2d_6… │
# │                     │ 64)               │            │                   │
# ...

# %%
def preprocess_image(image_path):
    """
    Preprocess an X-ray image for feature extraction.

    Args:
        image_path (str): Path to the X-ray image.

    Returns:
        np.array: Preprocessed image (224, 224, 3)
    """
    import cv2
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Could not read image: {image_path}")

    img = cv2.resize(img, (224, 224))  # Resize
    img = np.stack([img] * 3, axis=-1)  # Convert grayscale to RGB
    img = img / 255.0  # Normalize
    
    return img  # Shape: (224, 224, 3)  ✅ No extra batch dimension!

# %%
def extract_features_batch(image_paths, model, batch_size=32):
    """
    Extracts feature vectors for a batch of images.

    Args:
        image_paths (list): List of image file paths.
        model (tf.keras.Model): Feature extraction model.
        batch_size (int): Number of images to process per batch.

    Returns:
        np.array: Extracted feature vectors for all images.
    """
    all_features = []
    
    for i in range(0, len(image_paths), batch_size):
        batch_paths = image_paths[i:i+batch_size]
        batch_images = np.array([preprocess_image(img) for img in batch_paths])  # ✅ No extra dimension
        
        # Extract features in batch
        batch_features = model.predict(batch_images, verbose=0)  # Suppress logging
        all_features.append(batch_features)

    return np.vstack(all_features)  # Stack all features into a single NumPy array

# %%
import tensorflow as tf
import os

# Enable Apple Metal API for GPU acceleration
os.environ["TF_MPS_ENABLED"] = "1"

# Check if GPU is detected
if tf.config.list_physical_devices('GPU'):
    print("✅ GPU Available:", tf.config.list_physical_devices('GPU'))
else:
    print("❌ No GPU found. Running on CPU.")
# Out:
# ✅ GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
import numpy as np
from glob import glob

# Path to Indiana dataset
image_dir = "/Users/nuthankishoremaddineni/Desktop/Radiology_Data/NLMCXR_png"

# Get all image paths
image_paths = glob(os.path.join(image_dir, "*.png"))  # Adjust if images are in other formats

# Create an empty array to store feature vectors
all_features = []

# Extract features for all images
with tf.device('/device:GPU:0'):
    all_features = extract_features_batch(image_paths, feature_extractor, batch_size=32)


# Convert to NumPy array
all_features = np.array(all_features)

# Save extracted features for later use
np.save("indiana_xray_features.npy", all_features)

print(f"✅ Extracted features for {len(all_features)} images.")
print(f"Feature vectors shape: {all_features.shape}")  # Expected: (6000, 1024)
# Out:
# ✅ Extracted features for 7470 images.
# Feature vectors shape: (7470, 1024)

# %%
import os
import xml.etree.ElementTree as ET
import pandas as pd

# Path to Indiana dataset XML reports
XML_DIR = "/Users/nuthankishoremaddineni/Desktop/Radiology_Data/ecgen-radiology"

def parse_xml_report(xml_file):
    """
    Extracts the image ID and corresponding radiology report (FINDINGS + IMPRESSION) from an XML file.

    Args:
        xml_file (str): Path to the XML file.

    Returns:
        tuple: (image_id, findings_text, impression_text)
    """
    tree = ET.parse(xml_file)
    root = tree.getroot()

    # Extract image ID (matches extracted features)
    image_id_tag = root.find(".//parentImage")
    image_id = image_id_tag.get("id") if image_id_tag is not None else None

    # Initialize empty strings for findings & impression
    findings_text = ""
    impression_text = ""

    # Extract FINDINGS section (if available)
    findings_section = root.find(".//AbstractText[@Label='FINDINGS']")
    if findings_section is not None and findings_section.text:
        findings_text = findings_section.text.strip()

    # Extract IMPRESSION section (if available)
    impression_section = root.find(".//AbstractText[@Label='IMPRESSION']")
    if impression_section is not None and impression_section.text:
        impression_text = impression_section.text.strip()

    return image_id, findings_text, impression_text

# Process all XML files
xml_files = [os.path.join(XML_DIR, f) for f in os.listdir(XML_DIR) if f.endswith(".xml")]
reports_data = [parse_xml_report(xml) for xml in xml_files]

# Convert to DataFrame for easy handling
reports_df = pd.DataFrame(reports_data, columns=["image_id", "findings", "impression"])
print(reports_df.shape)  # Check extracted reports
# Out:
# (3955, 3)

# %%
import os
import numpy as np

# Load image filenames (without extensions)
image_dir = "/Users/nuthankishoremaddineni/Desktop/Radiology_Data/NLMCXR_png"
image_files = sorted(os.listdir(image_dir))  # Ensure sorting matches extraction order
image_ids = [os.path.splitext(f)[0] for f in image_files]  # Remove file extensions

# Load feature vectors
features = np.load("indiana_xray_features.npy")


# Find missing image ID
if len(image_ids) != len(features):
    print(f"❌ Mismatch found: {len(image_ids)} images but {len(features)} feature vectors.")

    # Identify missing ID
    missing_images = set(image_ids) - set(image_ids[:len(features)])  # Check last mismatched entry
    print(f"Missing Image ID: {missing_images}")
# Out:
# ❌ Mismatch found: 7471 images but 7470 feature vectors.
# Missing Image ID: {'CXR9_IM-2407-2001'}

# %%
import numpy as np
import os
import pandas as pd

# Load extracted X-ray features
features = np.load("indiana_xray_features.npy")  # Shape: (6000, 1024)

# Load image file names (ensuring correct order)
image_files = sorted(
    [f for f in os.listdir("/Users/nuthankishoremaddineni/Desktop/Radiology_Data/NLMCXR_png") 
     if f.lower().endswith(('.png', '.jpg', '.jpeg'))]  # Only image files
)

# Remove file extensions to match XML image IDs
image_ids = [os.path.splitext(f)[0] for f in image_files]
#image_ids = [img for img in image_ids if img != 'CXR9_IM-2407-2001']  # Corrected remove()

# Convert to DataFrame
features_df = pd.DataFrame(features, index=image_ids)
features_df.reset_index(inplace=True)
features_df.rename(columns={"index": "image_id"}, inplace=True)

# Convert `image_id` to string, lowercase, and remove extra spaces
features_df["image_id"] = features_df["image_id"].astype(str).str.lower().str.strip()
reports_df["image_id"] = reports_df["image_id"].astype(str).str.lower().str.strip()

# Debugging step: Print a few sample image IDs
print("Sample IDs in features_df:", features_df["image_id"].head(5).tolist())
print("Sample IDs in reports_df:", reports_df["image_id"].head(5).tolist())

# Check number of matching IDs
matching_ids = set(features_df["image_id"]).intersection(set(reports_df["image_id"]))
print(f"✅ Found {len(matching_ids)} common image_ids")

# Merge features with reports using "image_id"
final_dataset = pd.merge(features_df, reports_df, on="image_id", how="inner")

print(f"✅ Matched {len(final_dataset)} X-ray features with reports!")
print(final_dataset.head())

# Save final dataset
final_dataset.to_csv("indiana_features_reports.csv", index=False)
np.save("indiana_final_features.npy", final_dataset.to_numpy())
# Out:
# Sample IDs in features_df: ['cxr1000_im-0003-1001', 'cxr1000_im-0003-2001', 'cxr1000_im-0003-3001', 'cxr1001_im-0004-1001', 'cxr1001_im-0004-1002']
# Sample IDs in reports_df: ['cxr162_im-0401-1001', 'cxr1390_im-0249-1001', 'cxr604_im-2193-1001', 'cxr2699_im-1167-1001', 'cxr2841_im-1253-2001']
# ✅ Found 3851 common image_ids
# ✅ Matched 3851 X-ray features with reports!
#                image_id    0         1         2    3         4         5  \
# 0  cxr1000_im-0003-1001  0.0  0.002869  0.003848  0.0  0.046384  0.006569
# 1  cxr1001_im-0004-1001  0.0  0.002572  0.002487  0.0  0.065804  0.000000
# 2  cxr1002_im-0004-1001  0.0  0.002294  0.002989  0.0  0.062575  0.019089
# 3  cxr1003_im-0005-2002  0.0  0.002892  0.004581  0.0  0.040667  0.023741
# 4  cxr1004_im-0005-1001  0.0  0.003031  0.004264  0.0  0.039481  0.038450
#
#           6         7         8  ...      1016      1017      1018      1019  \
# 0  0.001710  0.000052  0.314484  ...  0.509030  0.617139  0.314528  0.594334
# ...

# %%
import numpy as np

# Load the .npy file
feature_vectors = np.load("indiana_xray_features.npy")

# Print shape and sample data
print("Shape of feature vectors:", feature_vectors.shape)
print("Sample feature vector:", feature_vectors[0])
# Out:
# Shape of feature vectors: (7470, 1024)
# Sample feature vector: [0.         0.00286927 0.00384831 ... 0.7952482  0.797332   0.6448715 ]
